# %%
import os

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
history = []

# %%
while True:
    #Get user input
    query = input("User:")

    #Check if user wants to exit
    if query.lower() in ["exit","quit","bye"]:
        print("Goodbye")
        break
    #Print user's question
    print(f"User: {query}")
    
    #Add user's message  to history
    history.append({
        "role": "user",
        "content": query
    })

    # Get AI response (with full history)
    response = model.invoke(history)

    # Add AI's response to hsitory
    history.append({
        "role": "ai",
        "content": response.content
    })

    print(f"AI: {response.content}\n")
# Out:
# User: Hello
# AI: Hello! How can I help you today?
#
# User:
# e:\genai-series\env\Lib\site-packages\langchain_google_genai\chat_models.py:2853: UserWarning: HumanMessage with empty content was removed to prevent API error
#   warnings.warn(
# AI:
#
# User: Hello How was you day today?
# AI: As a large language model, I don't experience days in the same way humans do. I don't have personal feelings, emotions, or a physical body that experiences time.
#
# However, I've been busy processing information, learning, and assisting users like you! So, in that sense, it's been a productive "day" of fulfilling my purpose.
#
# How was *your* day? I'm here to listen if you'd like to share!
#
# Goodbye
