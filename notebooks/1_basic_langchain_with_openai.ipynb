# %%
import os

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

# %%
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

# %%
response = model.invoke("Why do parrots talk?")
print(response.content)
# Out:
# Parrots talk for a variety of fascinating reasons, primarily rooted in their **social nature, intelligence, and evolutionary adaptations.** It's not quite like human speech, but it's a remarkable form of vocal mimicry and communication. Here's a breakdown of the main drivers:
#
# **1. Social Bonding and Flock Communication:**
#
# * **Maintaining Social Connections:** In the wild, parrots are highly social animals that live in flocks. Vocalizations are crucial for maintaining contact, identifying individuals, and coordinating activities within the group. Talking, or mimicking sounds, can be a way to reinforce these bonds and signal affiliation.
# * **Learning Flock Calls:** Young parrots learn the specific calls and vocalizations of their flock. This is essential for survival, as it helps them stay with the group, find food, and avoid predators. Mimicry is a key part of this learning process.
# * **"Practice" and Rehearsal:** Some researchers believe that parrots may practice vocalizations, including human speech, to refine their ability to communicate effectively within their social environment.
#
# **2. Intelligence and Cognitive Abilities:**
#
# * **High Intelligence:** Parrots are among the most intelligent birds. They have complex brains and are capable of learning, problem-solving, and understanding cause-and-effect. This intelligence allows them to process and reproduce sounds.
# * **Cognitive Stimulation:** For captive parrots, mimicking human speech can be a form of cognitive stimulation. It keeps their minds engaged and provides an outlet for their natural curiosity and learning abilities.
# * **Understanding Context (to a degree):** While they don't understand language in the same way humans do, some parrots can learn to associate certain words or phrases with specific objects, actions, or rewards. They might say "hello" when someone enters a room or "cracker" when they want a treat. This shows a level of contextual understanding.
#
# **3. Mimicry as a Survival Tool (in the wild):**
#
# * **Camouflage and Deception:** In their natural habitat, parrots might mimic the sounds of predators or other animals to avoid detection or to distract threats.
# * **Attracting Mates:** Some vocalizations, including mimicry, could potentially play a role in attracting mates by showcasing vocal prowess.
#
# **4. Captivity and Human Interaction:**
#
# * **Seeking Attention and Interaction:** In a captive environment, parrots often mimic human speech to get attention from their owners. They learn that making sounds gets a response, and this reinforces the behavior.
# * **Boredom and Lack of Stimulation:** If a parrot is bored or not sufficiently stimulated, it may resort to mimicking sounds as a way to entertain itself.
# * **Learned Behavior and Reinforcement:** Owners often inadvertently (or intentionally) reinforce talking by responding positively when their parrot vocalizes. This can be through praise, treats, or interaction.
#
# **It's important to distinguish between "talking" and true language comprehension:**
#
# * **Mimicry vs. Language:** When parrots "talk," they are primarily **mimicking sounds** they hear. They are not composing original sentences or understanding the abstract meaning of words in the way humans do.
# * **Contextual Association:** As mentioned, they can learn to associate sounds with specific contexts, which can appear like understanding. For example, a parrot might say "bye-bye" when someone leaves the room.
#
# **In summary, parrots talk because:**
#
# * **They are social creatures who use vocalizations to communicate and bond.**
# * **They are highly intelligent and have a remarkable capacity for learning and mimicry.**
# * **In captivity, talking can be a way to seek attention, alleviate boredom, and engage with their human companions.**
#
# It's a testament to their incredible cognitive abilities and their deep desire for social interaction that they can learn and reproduce such a wide range of sounds.
